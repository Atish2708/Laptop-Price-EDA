# %% [markdown]
# ### Cars DataFrame Assignment by Atish Landge

# %%
from warnings import filterwarnings
filterwarnings ('ignore')

# %%
import pandas as pd
path=r"D:\Pandas Assignment\Cars93.csv"
df=pd.read_csv(path,na_values=['','NA'],keep_default_na=False)
A=df
A
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %% [markdown]
# ### Q1: Find out car having highest Mileage in city

# %%
A.sort_values(by='MPG.city',ascending=False).head(5)
# Out:
#     id Manufacturer   Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo   Metro  Small        6.7    8.4       10.0        46
# 41  42        Honda   Civic  Small        8.4   12.1       15.8        42
# 82  83       Suzuki   Swift  Small        7.3    8.6       10.0        39
# 79  80       Subaru   Justy  Small        7.3    8.4        9.5        33
# 83  84       Toyota  Tercel  Small        7.8    9.8       11.8        32
#
#     MPG.highway      AirBags  ... Passengers Length  Wheelbase  Width  \
# 38           50         None  ...          4    151         93     63
# 41           46  Driver only  ...          4    173        103     67
# 82           43         None  ...          4    161         93     63
# 79           37         None  ...          4    146         90     60
# 83           37  Driver only  ...          5    162         94     65
#
#     Turn.circle  Rear.seat.room Luggage.room  Weight   Origin           Make
# ...

# %% [markdown]
# ### Q2:Find out Models of cars which are having Price between 17 and 25

# %%
fil1 =A['Price']>=17
fil2 =A['Price']<=25
fil=fil1 & fil2
A[fil]
# Out:
#     id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 6    7        Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick      Roadmaster    Large       22.6   23.7       24.9
# 17  18    Chevrolet         Caprice    Large       18.0   18.8       19.6
# 19  20     Chrylser        Concorde    Large       18.4   18.4       18.4
# 25  26        Dodge         Caravan      Van       13.6   19.0       24.4
# 29  30        Eagle          Vision    Large       17.5   19.3       21.2
# 35  36         Ford        Aerostar      Van       14.5   19.9       25.3
# 36  37         Ford          Taurus  Midsize       15.6   20.2       24.8
# 37  38         Ford  Crown_Victoria    Large       20.1   20.9       21.7
# 40  41        Honda         Prelude   Sporty       17.0   19.8       22.7
# 42  43        Honda          Accord  Compact       13.8   17.5       21.2
# 55  56        Mazda             MPV      Van       16.6   19.1       21.7
# ...

# %%
A.query("Price>=17 and Price<=25")
# Out:
#     id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 6    7        Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick      Roadmaster    Large       22.6   23.7       24.9
# 17  18    Chevrolet         Caprice    Large       18.0   18.8       19.6
# 19  20     Chrylser        Concorde    Large       18.4   18.4       18.4
# 25  26        Dodge         Caravan      Van       13.6   19.0       24.4
# 29  30        Eagle          Vision    Large       17.5   19.3       21.2
# 35  36         Ford        Aerostar      Van       14.5   19.9       25.3
# 36  37         Ford          Taurus  Midsize       15.6   20.2       24.8
# 37  38         Ford  Crown_Victoria    Large       20.1   20.9       21.7
# 40  41        Honda         Prelude   Sporty       17.0   19.8       22.7
# 42  43        Honda          Accord  Compact       13.8   17.5       21.2
# 55  56        Mazda             MPV      Van       16.6   19.1       21.7
# ...

# %% [markdown]
# ### Q3: Find out top 7 most fuel economic cars for highway

# %%
A.sort_values(by='MPG.highway',ascending=False).head(7)[['Manufacturer','Model','MPG.highway']]
# Out:
#    Manufacturer   Model  MPG.highway
# 38          Geo   Metro           50
# 41        Honda   Civic           46
# 82       Suzuki   Swift           43
# 72      Pontiac  LeMans           41
# 78       Saturn      SL           38
# 83       Toyota  Tercel           37
# 79       Subaru   Justy           37

# %% [markdown]
# ### Q4:Find out Models of cars having no AirBags and which are of compact type whose price is below 20.

# %%
fil1=A['AirBags']=='None'
fil2=A['Type']=='Compact'
fil3=A['Price']<=20
fil=(fil1 & fil2 & fil3)
A[fil]
# Out:
#     id Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 11  12    Chevrolet  Cavalier  Compact        8.5   13.4       18.3        25
# 32  33         Ford     Tempo  Compact       10.4   11.3       12.2        22
# 67  68   Oldsmobile   Achieva  Compact       13.0   13.5       14.0        24
# 73  74      Pontiac   Sunbird  Compact        9.4   11.1       12.8        23
# 89  90   Volkswagen    Passat  Compact       17.6   20.0       22.4        21
#
#     MPG.highway AirBags  ... Passengers Length  Wheelbase  Width  Turn.circle  \
# 11           36    None  ...          5    182        101     66           38
# 32           27    None  ...          5    177        100     68           39
# 67           31    None  ...          5    188        103     67           39
# 73           31    None  ...          5    181        101     66           39
# 89           30    None  ...          5    180        103     67           35
#
# ...

# %%
A.query("(AirBags=='None' and Type=='Compact' and Price<=20)")
# Out:
#     id Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 11  12    Chevrolet  Cavalier  Compact        8.5   13.4       18.3        25
# 32  33         Ford     Tempo  Compact       10.4   11.3       12.2        22
# 67  68   Oldsmobile   Achieva  Compact       13.0   13.5       14.0        24
# 73  74      Pontiac   Sunbird  Compact        9.4   11.1       12.8        23
# 89  90   Volkswagen    Passat  Compact       17.6   20.0       22.4        21
#
#     MPG.highway AirBags  ... Passengers Length  Wheelbase  Width  Turn.circle  \
# 11           36    None  ...          5    182        101     66           38
# 32           27    None  ...          5    177        100     68           39
# 67           31    None  ...          5    188        103     67           39
# 73           31    None  ...          5    181        101     66           39
# 89           30    None  ...          5    180        103     67           35
#
# ...

# %% [markdown]
# ### Q5:Find out top 7 most fuel economic cars for city, show results in sorted manner based on Horsepower.

# %%
A.nlargest(7,'MPG.city')[['Model','MPG.city','Horsepower']]
# Out:
#       Model  MPG.city  Horsepower
# 38    Metro        46          55
# 41    Civic        42         102
# 82    Swift        39          70
# 79    Justy        33          73
# 83   Tercel        32          82
# 30  Festiva        31          63
# 72   LeMans        31          74

# %% [markdown]
# ### Step 2

# %%
B=A.sort_values(by='MPG.city' ,ascending=False).head(7)[["Manufacturer",
                                                           "Model",
                                                           "MPG.city",
    
                                                         "Horsepower"]]
B
# Out:
#    Manufacturer    Model  MPG.city  Horsepower
# 38          Geo    Metro        46          55
# 41        Honda    Civic        42         102
# 82       Suzuki    Swift        39          70
# 79       Subaru    Justy        33          73
# 83       Toyota   Tercel        32          82
# 72      Pontiac   LeMans        31          74
# 30         Ford  Festiva        31          63

# %%
B.sort_values(by='Horsepower',ascending=False)
# Out:
#    Manufacturer    Model  MPG.city  Horsepower
# 41        Honda    Civic        42         102
# 83       Toyota   Tercel        32          82
# 72      Pontiac   LeMans        31          74
# 79       Subaru    Justy        33          73
# 82       Suzuki    Swift        39          70
# 30         Ford  Festiva        31          63
# 38          Geo    Metro        46          55

# %% [markdown]
# ###### Q6:Find out Cars having mileage of more than 15 miles in city

# %%
fil3=A[A['MPG.city']>15]
fil3
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %% [markdown]
# ### Step 2

# %%
A.query("`MPG.city`>15")
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %% [markdown]
# ### Q7:Find out Cars with US based origin¶

# %%
A.query("Origin=='USA'")[['Model','Manufacturer','Origin']]
# Out:
#              Model Manufacturer Origin
# 5          Century        Buick    USA
# 6          LeSabre        Buick    USA
# 7       Roadmaster        Buick    USA
# 8          Riviera        Buick    USA
# 9          DeVille     Cadillac    USA
# 10         Seville     Cadillac    USA
# 11        Cavalier    Chevrolet    USA
# 12         Corsica    Chevrolet    USA
# 13          Camaro    Chevrolet    USA
# 14          Lumina    Chevrolet    USA
# 15      Lumina_APV    Chevrolet    USA
# 16           Astro    Chevrolet    USA
# 17         Caprice    Chevrolet    USA
# 18        Corvette    Chevrolet    USA
# 19        Concorde     Chrylser    USA
# 20         LeBaron     Chrysler    USA
# 21        Imperial     Chrysler    USA
# 22            Colt        Dodge    USA
# 23          Shadow        Dodge    USA
# 24          Spirit        Dodge    USA
# 25         Caravan        Dodge    USA
# 26         Dynasty        Dodge    USA
# 27         Stealth        Dodge    USA
# ...

# %% [markdown]
# ### Q8:Find out Cars with no airbags and which are compact in type, from the output retrieve only Model, Mileage in city, Type, Airbags

# %%
A.query("AirBags=='None'and Type=='Compact'")[['Model',
                                            'MPG.city',
                                        'Type','AirBags']]
# Out:
#        Model  MPG.city     Type AirBags
# 11  Cavalier        25  Compact    None
# 32     Tempo        22  Compact    None
# 67   Achieva        24  Compact    None
# 73   Sunbird        23  Compact    None
# 89    Passat        21  Compact    None

# %% [markdown]
# ### Q9: Find out cars with Mileage in city more than 15 which are compact in type.

# %%
A.query("`MPG.city`>=15 and Type=='Compact'")[['Model','MPG.city']]
# Out:
#        Model  MPG.city
# 2         90        20
# 11  Cavalier        25
# 12   Corsica        25
# 20   LeBaron        23
# 24    Spirit        22
# 32     Tempo        22
# 42    Accord        24
# 54       626        26
# 57      190E        20
# 64    Altima        24
# 67   Achieva        24
# 73   Sunbird        23
# 77       900        20
# 81    Legacy        23
# 89    Passat        21
# 91       240        21
